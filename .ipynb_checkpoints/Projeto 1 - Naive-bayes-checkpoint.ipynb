# %%
import pandas as pd
import numpy as np
from IPython.display import display
pd.options.display.max_rows = 13
import math
import random

# %%
import re 
import sys
import functools
import operator
import emoji

def cleanup(text):
    """
        Função de limpeza muito simples que troca alguns sinais básicos por espaços
    """
    #import string
    punctuation = '[!-.:?;]' # Note que os sinais [] são delimitadores de um conjunto.
    pattern = re.compile(punctuation)
    text_subbed = re.sub(pattern, '', text)
    return text_subbed

def remove_arroba(lista):
    arroba = "@"
    for i in lista: 
        if arroba in i:
            lista.remove(i)
    return lista
def remove_link(lista):
    link = "/"
    for i in lista: 
        if link in i:
            lista.remove(i)
    return lista
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-0d5b2b006292> in <module>
#       3 import functools
#       4 import operator
# ----> 5 import emoji
#       6
#       7 def cleanup(text):
#
# ModuleNotFoundError: No module named 'emoji'

# %%
#treinamento
dados = pd.read_excel('Iphone_CDados.xlsx')

#teste
excel = pd.ExcelFile('Iphone_CDados.xlsx')
teste = pd.read_excel(excel, 'Teste')

# %%
dados
# Out:
#                                            Treinamento  Filtro
# 0    @kayllanefer bateria de iphone é uma merda, ja...       1
# 1             cabo de iphone eh feito pra estragar pqp       1
# 2    @johnpvx melhor iphone de sempre. não me arrep...       1
# 3    alguém querendo comprar um cabo/carregador de ...       1
# 4    to sem carregador já tava sofrendo aqui daí le...       1
# ..                                                 ...     ...
# 328              acho que amanhã lança o iphone 12 👀👀👀       0
# 329  @pirucaking @paulocoelho não dá pra levar a sé...       0
# 330  to querendo comprar o iphone 11pro max, para m...       0
# 331  triste tirar foto só com iphone 😔 pois é a úni...       0
# 332  um amigo meu vai se alistar na cruz vermelha e...       0
#
# [333 rows x 2 columns]

# %%
Relevante = dados["Filtro"].isin(["1"])
Irrelevante = dados["Filtro"].isin(["0"])
Relevante = dados.loc[Relevante, :]
Irrelevante = dados.loc[Irrelevante, :]


total_frases_relevantes = Relevante.count()[0]
total_frases_irrelevantes = Irrelevante.count()[0]

# %%
#limpando texto e fazendo lista

Treino_Relevante = Relevante["Treinamento"]
Treino_Irrelevante = Irrelevante["Treinamento"]

def make_list(Treino_Relevante):
    
    treinamento_relevante = []

    #fazendo lista
    for i in Treino_Relevante:
        treinamento_relevante.append(i)
        
    
    coma = "'"
    #transformar em texto
    treinamento_relevante = coma.join(treinamento_relevante)

    #função que limpa
    limpa = cleanup(treinamento_relevante)
    #no_emoji = remove_emoji(limpa)

    #lista por palavra
    minusculo = limpa.lower()
    
    palavras_relevantes = minusculo.split()
    lista_nova = []
    
    for i in palavras_relevantes: 
        em_split_emoji = emoji.get_emoji_regexp().split(i)
        em_split_whitespace = [o.split() for o in em_split_emoji]
        em_split = functools.reduce(operator.concat, em_split_whitespace)
        lista_nova.append(em_split)
    
    lista_emoji = []
    for w in lista_nova:
        for j in w:
            lista_emoji.append(j)
    
    
    lista = remove_arroba(lista_emoji)
    lista = remove_link(lista)
    print (lista_emoji)
    return lista

todas_palavras_relevantes = make_list(Treino_Relevante)
todas_palavras_irrelevantes = make_list(Treino_Irrelevante)
print(todas_palavras_relevantes)
# Out:
# ['bateria', 'de', 'iphone', 'é', 'uma', 'merda', 'ja', 'carreguei', 'o', 'meu', 'umas', '4x', 'hj', 'kkkcabo', 'de', 'iphone', 'eh', 'feito', 'pra', 'estragar', 'melhor', 'iphone', 'de', 'sempre', 'não', 'me', 'arrependo', 'nada', 'e', 'foi', 'logo', 'o', 'maior', 'porque', 'se', 'é', 'para', 'ser', 'é', 'para', 'ser', 'em', 'bomalguém', 'querendo', 'comprar', 'um', 'de', 'iphone', 'achei', 'uma', 'promoção', 'que', 'vem', 'dois', 'por', 'um', 'valor', 'x', 'que', 'é', 'mais', 'barato', 'que', 'comprar', 'apenas', 'um', 'tudo', 'o', 'olho', 'da', 'cara', 'mas', 'necessitado', 'do', 'item', 'estou', 'quem', 'vamos', 'meajudaqueteajudoto', 'sem', 'carregador', 'já', 'tava', 'sofrendo', 'aqui', 'daí', 'lembrei', 'que', 'aqui', 'em', 'casa', 'agora', 'todo', 'mundo', 'tem', 'iphone', '11', 'miga', 'não', 'desvaloriza', 'no', 'iphone', 'buga', 'q', 'ódio', '🤡', 'bateria', 'do', 'iphone', 'pq', 'tão', 'merdao', 'iphone', 'já', 'é', 'caro', 'com', 'um', 'símbolo', 'de', 'uma', 'maçã', 'imagine', 'se', 'fosse', 'um', 'feijão', '🤔', '💭', 'rt', 'ah', 'pronto', 'agora', 'quero', 'o', 'iphone', '11', 'lilás', 'eu', 'to', 'apaixonado', 'naquela', 'cor', '💜', 'todo', 'iphone', 'fica', 'merda', 'depois', 'de', '2', 'anos', 'kkkkkknão', 'consigo', 'enviar', 'vídeo', 'longo', 'por', 'wpp', 'pra', 'minha', 'mãe', 'e', 'nem', 'por', 'bluetooth', 'pq', 'meu', 'celular', 'eh', 'iphone', 'apelarei', 'para', 'o', 'telegram', '🙏🏻', 'tá', 'ligado', 'aquele', 'medo', 'de', 'atualizar', 'o', 'iphone', 'e', 'dar', 'merda', 'kkkquase', 'quebrei', 'um', 'iphone', 'x', 'e', 'por', 'um', 'segundo', 'já', 'pensei', 'em', 'qual', 'dos', 'rins', 'mas', 'assim', 'o', 'a10', 'é', 'melhor', 'e', 'ainda', 'por', 'cima', 'mais', 'barato', 'porém', 'o', 'iphone', '6', 'tem', 'uma', 'câmera', 'melhor', 'mas', 'tem', 'um', 'custo', 'benefício', 'mais', 'alto', 'e', 'ainda', 'não', 'recebe', 'mais', 'atualizações', 'kkkkkkkkk', 'te', 'confundi', 'maistanta', 'gente', 'me', 'seguindo', 'conseguiram', 'fazer', 'o', 'iphone', 'trava', 'kkkkkkkkkkkkodeio', 'o', 'leitor', 'de', 'tela', 'do', 'iphoneesqueci', 'q', 'iphone', 'trava', 'quando', 'tá', '1', 'de', 'bateria', '🗣', '🗣', 'a', 'gente', 'queria', 'iphone', 'mas', 'tem', 'samsung', 'kkkk', 'do', 'iphone', 'é', 'horrível', '🤦🏻\u200d♂️', 'bateria', 'de', 'iphone', 'e', 'um', 'cu', 'msm', 'né', 'pq', 'quando', 'quer', 'vender', 'essa', 'merda', 'a', 'pessoa', 'fica', 'interessada', 'aí', 'vai', 'perguntar', 'da', 'bateria', 'e', 'desiste', '😓', 'rt', 'apagar', 'contactos', 'no', 'iphone', 'da', 'mt', 'trabalho', 'próxima', 'atualização', 'facilitem', 'o', 'processo', 'pls', 'coloquem', 'opção', 'de', 'selecionar', 'vários…ganhei', 'um', 'iphone', 'de', 'aniversário', 'aaaaaaaaa', 'to', 'feliz', 'demaisbateria', 'de', 'iphone', 'eh', 'ruim', 'demais', 'cê', 'eh', 'lokoah', 'pronto', 'agora', 'quero', 'o', 'iphone', '11', 'lilás', 'eu', 'to', 'apaixonado', 'naquela', 'cor', '💜', 'talvez', 'seja', 'a', 'atualização', 'do', 'iphone', 'q', 'veio', 'com', 'bugs', 'pq', 'as', 'vezes', 'tem', 'uns', 'apps', 'meus', 'que', 'sai', 'do', 'nadaiphone', '12', 'pro', 'vídeo', 'mostra', 'design', 'retrô', 'inspirado', 'no', 'iphone', '4', 'gt', 'apple', 'smartphonesrt', 'o', 'novo', 'iphone', 'se', 'é', 'oficial', '📲', 'parece', 'um', 'iphone', '8', 'com', 'tudo', 'do', 'iphone', '11', '🤞', 'touchid', '📸', 'única', 'câmera', '12mp', '🧠', 'processador', 'b…infelizmente', 'nós', 'usuários', 'de', 'iphone', 'não', 'poderemos', 'usar', 'o', 'xcloud', 'sempre', 'gostei', 'muito', 'de', 'ios', 'mas', 'talvez', 'hoje', 'pela', '1', 'vez', 'consideraria', 'comprar', 'um', 'androide', 'mas', 'só', 'que', 'não', 'rsrsrsrs', 'iphone', 'é', 'maravilhoso', 'só', 'seria', 'melhor', 'se', 'tivesse', 'a', 'bateria', 'do', 'motorola', 'e', 'o', 'preço', 'do', 'samsungiphone', 'eu', 'desisto', 'de', 'vc', '💀', 'portadores', 'de', 'iphone', 'tem', 'q', 'carregar', 'o', 'celular', '3', 'vezes', 'por', 'minha', 'irmã', 'comprou', 'um', 'iphone', 'lá', 'no',  ...
# ['só', 'mandar', 'eu', 'tenho', 'iphone', 'e', 'travaram', 'o', 'meu', 'zap', 'uns', 'dias', '@andrizek', 'já', 'parei', 'de', 'assistir', 'ao', 'por', 'conta', 'dele', 'menos', 'mal', 'aturar', 'o', 'comunistinha', 'de', 'iphone', 'flávio', 'gomes', 'eca', 'do', 'que', 'este', 'aí', 'a', 'espn', 'parece', 'que', 'tá', 'se', 'livrando', 'de', 'alguns', 'vermelhos', 'talvez', 'eu', 'volte', 'a', '@maduu_1503', '@_yaguinb2', 'o', 'twitter', 'pra', 'iphone', 'aparece', 'a', 'palavra', 'mil', 'o', 'twitter', 'pra', 'android', 'aparece', 'a', 'letra', '@jujumfrancoo', 'aaaaa', 'kkkk', 'nem', 'sabia', 'jurava', 'que', 'era', 'boa', 'iniciativa', 'da', 'uerj', 'só', 'espero', 'que', 'receba', 'quem', 'realmente', 'esteja', 'precisando', 'pois', 'chip', 'pago', 'com', 'dinheiro', 'público', 'em', 'iphone', 'é', 'complicado', '@btsxbrazil', 'onde', 'eu', 'encontro', 'a', 'musica', 'que', 'ganhei', 'de', 'presente', 'no', 'app', 'pelo', 'iphone', 'por', 'favor', 'alguem', 'me', 'ajuda', 'meu', 'pai', 'acabou', 'de', 'dar', 'um', 'iphone', 'x', 'pra', 'minha', 'mae', 'queria', 'ta', 'em', 'um', 'relacionamento', 'eu', 'também', 'acho', 'q', 'ela', 'usa', 'iphone', 'escondido', 'se', 'bem', 'que', 'os', 'últimos', 'samsung’s', 'estão', 'bonse', 'eu', 'q', 'achava', 'q', 'eu', 'ficaria', 'bnt', 'nas', 'fotos', 'do', 'iphonealguém', 'com', 'iphone', 'tira', 'print', 'do', 'meu', 'perfil', '🥺', 'sou', 'jovem', 'comunista', 'sim', 'e', 'com', 'orgulho', 'twitter', 'for', 'poliglota', 'ala', 'porém', 'é', 'uma', 'pena', 'parece', 'que', 'eu', 'vi', 'um', 'twitter', 'for', 'iphone', 'logo', 'tudo', 'q', 'vc', 'diz', 'é', 'anulado', 'kkkkkkkmentira', 'era', 'ser', 'magra', 'e', 'um', 'iphone', '11amigos', 'q', 'vivem', 'trocando', 'de', 'iphone', 'vcs', 'não', 'tem', 'um', 'fone', 'ou', 'um', 'adaptador', 'pra', 'mim', '@eurapha7', 'mais', 'um', 'iphone', 'pro', 'carart', '❌', 'atenção', 'pro', 'amigo', 'aqui', '❌', 'hoje', 'no', 'baile', 'de', 'moscow', 'eu', 'perdi', 'meu', 'o', 'celular', 'iphone', '7', 'plus', 'cinza', 'com', 'a', 'capinha', 'preta', 'quem…não', 'fiquei', 'com', 'o', 'iphone', '11', 'mas', 'fiquei', 'com', 'o', 'fone', 'pelo', 'menos', 'kkkkkkalguém', 'com', 'iphone', 'tira', 'print', 'do', 'meu', 'perfil', 'pfv', '🥺', 'boa', 'vou', 'roubar', 'da', 'minha', 'prima', 'q', 'é', 'um', 'iphoneé', 'melhor', 'atacar', 'o', 'capitalismo', 'e', 'defender', 'os', 'outros', 'defender', 'o', 'comunismo', 'através', 'do', 'twitter', 'para', 'iphone', 'como', 'é', 'que', 'és', 'anti', 'capitalismo', 'mas', 'compras', 'produtos', 'da', 'apple', 'quiser', 'me', 'dar', 'um', 'carregador', 'de', 'iphone', 'eu', 'vou', 'agradecer', 'e', 'se', 'tu', 'aparecer', 'com', 'iphone', 'de', 'novo', 'isabelart', 'pra', 'todo', 'mudo', 'que', 'não', 'gosta', 'da', 'socialistinha', 'de', 'iphone', 'vão', 'tomar', 'no', 'cu', 'ela', 'é', 'incrível', 'pra', 'caralho', '🖕', '🖕', '🖕', '🖕', '🖕', '🖕', '🖕', 'é', 'serio', 'isso', 'da', 'para', 'comprar', 'um', 'iphone', 'com', 'esse', 'dinheiro', 'krt', 'não', 'vai', 'ter', 'eu', 'pegando', 'um', 'iphone', '11', 'fim', 'do', 'ano', '😭', 'alguém', 'me', 'da', 'um', 'fone', 'de', 'iphone', '🥺', 'gente', 'boa', 'tarde', 'se', 'vcs', 'não', 'sabem', 'tirar', 'a', 'capa', 'meu', 'iphone', 'não', 'tentem', 'pq', 'se', 'quebrar', 'eu', 'vou', 'querer', 'outra', '😄', 'não', 'vai', 'ter', 'eu', 'com', 'iphone', 'kkm', 'até', 'um', 'iphone', '5s', 'perdido', 'kkkkkrt', 'já', 'estou', 'a', 'ver', 'jordan’s', 'iphone', '12', 'roupa', 'a', 'dizer', 'chega', '😻', '😻', '😻', 'hnmmm', 'mãe', '😻', 'moça', 'linda', 'que', 'estava', 'no', 'hospital', 'de', 'fraturas', 'no', 'alto', 'da', 'xv', 'às', '1440', 'usando', 'um', 'shorts', 'jeans', 'branco', 'e', 'blusa', 'preta', 'se', 'não', 'me', 'engano', 'por', 'favor', 'precisamos', 'troca', 'uma', 'ideia', 'kkkkk', 'estava', 'com', 'um', 'iphone', '8plus', 'com', 'capinha', 'rosa', 'ajuda', 'ai', 'famíliaart', 'agora', 'além', 'dos', 'perfumes', 'e', 'hidratantes', 'importados', ' ...
# ['bateria', 'de', 'iphone', 'é', 'uma', 'merda', 'ja', 'carreguei', 'o', 'meu', 'umas', '4x', 'hj', 'kkkcabo', 'de', 'iphone', 'eh', 'feito', 'pra', 'estragar', 'melhor', 'iphone', 'de', 'sempre', 'não', 'me', 'arrependo', 'nada', 'e', 'foi', 'logo', 'o', 'maior', 'porque', 'se', 'é', 'para', 'ser', 'é', 'para', 'ser', 'em', 'bomalguém', 'querendo', 'comprar', 'um', 'de', 'iphone', 'achei', 'uma', 'promoção', 'que', 'vem', 'dois', 'por', 'um', 'valor', 'x', 'que', 'é', 'mais', 'barato', 'que', 'comprar', 'apenas', 'um', 'tudo', 'o', 'olho', 'da', 'cara', 'mas', 'necessitado', 'do', 'item', 'estou', 'quem', 'vamos', 'meajudaqueteajudoto', 'sem', 'carregador', 'já', 'tava', 'sofrendo', 'aqui', 'daí', 'lembrei', 'que', 'aqui', 'em', 'casa', 'agora', 'todo', 'mundo', 'tem', 'iphone', '11', 'miga', 'não', 'desvaloriza', 'no', 'iphone', 'buga', 'q', 'ódio', '🤡', 'bateria', 'do', 'iphone', 'pq', 'tão', 'merdao', 'iphone', 'já', 'é', 'caro', 'com', 'um', 'símbolo', 'de', 'uma', 'maçã', 'imagine', 'se', 'fosse', 'um', 'feijão', '🤔', '💭', 'rt', 'ah', 'pronto', 'agora', 'quero', 'o', 'iphone', '11', 'lilás', 'eu', 'to', 'apaixonado', 'naquela', 'cor', '💜', 'todo', 'iphone', 'fica', 'merda', 'depois', 'de', '2', 'anos', 'kkkkkknão', 'consigo', 'enviar', 'vídeo', 'longo', 'por', 'wpp', 'pra', 'minha', 'mãe', 'e', 'nem', 'por', 'bluetooth', 'pq', 'meu', 'celular', 'eh', 'iphone', 'apelarei', 'para', 'o', 'telegram', '🙏🏻', 'tá', 'ligado', 'aquele', 'medo', 'de', 'atualizar', 'o', 'iphone', 'e', 'dar', 'merda', 'kkkquase', 'quebrei', 'um', 'iphone', 'x', 'e', 'por', 'um', 'segundo', 'já', 'pensei', 'em', 'qual', 'dos', 'rins', 'mas', 'assim', 'o', 'a10', 'é', 'melhor', 'e', 'ainda', 'por', 'cima', 'mais', 'barato', 'porém', 'o', 'iphone', '6', 'tem', 'uma', 'câmera', 'melhor', 'mas', 'tem', 'um', 'custo', 'benefício', 'mais', 'alto', 'e', 'ainda', 'não', 'recebe', 'mais', 'atualizações', 'kkkkkkkkk', 'te', 'confundi', 'maistanta', 'gente', 'me', 'seguindo', 'conseguiram', 'fazer', 'o', 'iphone', 'trava', 'kkkkkkkkkkkkodeio', 'o', 'leitor', 'de', 'tela', 'do', 'iphoneesqueci', 'q', 'iphone', 'trava', 'quando', 'tá', '1', 'de', 'bateria', '🗣', '🗣', 'a', 'gente', 'queria', 'iphone', 'mas', 'tem', 'samsung', 'kkkk', 'do', 'iphone', 'é', 'horrível', '🤦🏻\u200d♂️', 'bateria', 'de', 'iphone', 'e', 'um', 'cu', 'msm', 'né', 'pq', 'quando', 'quer', 'vender', 'essa', 'merda', 'a', 'pessoa', 'fica', 'interessada', 'aí', 'vai', 'perguntar', 'da', 'bateria', 'e', 'desiste', '😓', 'rt', 'apagar', 'contactos', 'no', 'iphone', 'da', 'mt', 'trabalho', 'próxima', 'atualização', 'facilitem', 'o', 'processo', 'pls', 'coloquem', 'opção', 'de', 'selecionar', 'vários…ganhei', 'um', 'iphone', 'de', 'aniversário', 'aaaaaaaaa', 'to', 'feliz', 'demaisbateria', 'de', 'iphone', 'eh', 'ruim', 'demais', 'cê', 'eh', 'lokoah', 'pronto', 'agora', 'quero', 'o', 'iphone', '11', 'lilás', 'eu', 'to', 'apaixonado', 'naquela', 'cor', '💜', 'talvez', 'seja', 'a', 'atualização', 'do', 'iphone', 'q', 'veio', 'com', 'bugs', 'pq', 'as', 'vezes', 'tem', 'uns', 'apps', 'meus', 'que', 'sai', 'do', 'nadaiphone', '12', 'pro', 'vídeo', 'mostra', 'design', 'retrô', 'inspirado', 'no', 'iphone', '4', 'gt', 'apple', 'smartphonesrt', 'o', 'novo', 'iphone', 'se', 'é', 'oficial', '📲', 'parece', 'um', 'iphone', '8', 'com', 'tudo', 'do', 'iphone', '11', '🤞', 'touchid', '📸', 'única', 'câmera', '12mp', '🧠', 'processador', 'b…infelizmente', 'nós', 'usuários', 'de', 'iphone', 'não', 'poderemos', 'usar', 'o', 'xcloud', 'sempre', 'gostei', 'muito', 'de', 'ios', 'mas', 'talvez', 'hoje', 'pela', '1', 'vez', 'consideraria', 'comprar', 'um', 'androide', 'mas', 'só', 'que', 'não', 'rsrsrsrs', 'iphone', 'é', 'maravilhoso', 'só', 'seria', 'melhor', 'se', 'tivesse', 'a', 'bateria', 'do', 'motorola', 'e', 'o', 'preço', 'do', 'samsungiphone', 'eu', 'desisto', 'de', 'vc', '💀', 'portadores', 'de', 'iphone', 'tem', 'q', 'carregar', 'o', 'celular', '3', 'vezes', 'por', 'minha', 'irmã', 'comprou', 'um', 'iphone', 'lá', 'no',  ...

# %%
#pdSeries
serie_relevante = pd.Series(todas_palavras_relevantes)
serie_irrelevante = pd.Series(todas_palavras_irrelevantes)

# %%
#tabelas frequencia relativas
tabela_relevantes = serie_relevante.value_counts()
tabela_irrelevantes = serie_irrelevante.value_counts()
Nr = sum(tabela_relevantes)
Ni = sum(tabela_irrelevantes)

# %%
def limpa(tweet):
    pri = cleanup(tweet)
    #seg = remove_emoji(pri)
    
    return pri

# %%
#P(frase/relevante)
def P_tweet_dado_relevante(lista):
    
    prob_tweet_dado_relevante = 0
    alpha = 1
    V = 100000
    prob_tweets = []
    
    for tweet in lista:
        
        
        prob_tweet_dado_relevante = 0
        tweet_minusculo = tweet.lower()
        
        
        tweet_limpo = limpa(tweet_minusculo) 
        lista_limpo = tweet_limpo.split()
        
        lista_nova = []
    
        for i in lista_limpo: 
            em_split_emoji = emoji.get_emoji_regexp().split(i)
            em_split_whitespace = [o.split() for o in em_split_emoji]
            em_split = functools.reduce(operator.concat, em_split_whitespace)
            lista_nova.append(em_split)
    
        lista_emoji = []
        for w in lista_nova:
            for j in w:
                lista_emoji.append(j)
        
        lista_limpo = remove_arroba(lista_emoji)
        lista_limpo = remove_link(lista_limpo)
    
        for palavra in lista_limpo:
        
            if palavra in tabela_relevantes:
                prob_palavra_dado_relevante = (tabela_relevantes[palavra] + alpha)/ (Nr+(V * alpha))
        
            else:
            
                prob_palavra_dado_relevante = alpha/(Nr + (alpha * V))
            
            prob_tweet_dado_relevante += math.log(prob_palavra_dado_relevante)
        
        prob_tweets.append(prob_tweet_dado_relevante)
        
    return prob_tweets


#P(frase/irrelevante)
def P_tweet_dado_irrelevante(lista):
    
    prob_tweet_dado_irrelevante = 0
    alpha = 1
    V = 100000
    
    prob_tweets = []
    
    for tweet in lista:
        
        
        prob_tweet_dado_irrelevante = 0
        tweet_minusculo = tweet.lower()
        tweet_limpo = limpa(tweet_minusculo)
        lista_limpo = tweet_limpo.split()
        
        for i in lista_limpo: 
            em_split_emoji = emoji.get_emoji_regexp().split(i)
            em_split_whitespace = [o.split() for o in em_split_emoji]
            em_split = functools.reduce(operator.concat, em_split_whitespace)
            lista_nova.append(em_split)
    
        lista_emoji = []
        for w in lista_nova:
            for j in w:
                lista_emoji.append(j)
        
        
        lista_limpo = remove_arroba(lista_emoji)
        lista_limpo = remove_link(lista_limpo)
        
        for palavra in lista_limpo:
        
            if palavra in tabela_irrelevantes:
                prob_palavra_dado_irrelevante = (tabela_irrelevantes[palavra] + alpha)/ (Ni+(V * alpha))
        
            else:
            
                prob_palavra_dado_irrelevante = alpha/(Ni + (alpha * V))
            
            prob_tweet_dado_irrelevante += math.log(prob_palavra_dado_irrelevante)
        
        prob_tweets.append(prob_tweet_dado_irrelevante)
        
    return prob_tweets

# %%
#prob relevante
P_R = total_frases_relevantes/(total_frases_relevantes+total_frases_irrelevantes)
#prob irrelevante
P_I = 1 - P_R

# %%
teste_relevante = teste["Filtro"].isin(["1"])
teste_irrelevante = teste["Filtro"].isin(["0"])
Teste_Relevante = teste.loc[teste_relevante, :]
Teste_Irrelevante = teste.loc[teste_irrelevante, :]



def lista_treino(data_frame):
    
    lista_teste = []
    
    for i in data_frame["Teste"]:
        lista_teste.append(i)
        
    return lista_teste

lista_teste = lista_treino(teste)

# %%
Prob_tweet_dado_relevante = P_tweet_dado_relevante(lista_teste)
Prob_tweet_dado_irrelevante = P_tweet_dado_irrelevante(lista_teste)

# %%
Prob_relevante_dado_tweet = [i + math.log(P_R) for i in Prob_tweet_dado_relevante]
Prob_irrelevante_dado_tweet = [i + math.log(P_I) for i in Prob_tweet_dado_irrelevante]

# %%
valor_maior = []

for i in range(len(Prob_relevante_dado_tweet)):
    if Prob_relevante_dado_tweet[i] > Prob_irrelevante_dado_tweet[i]:
        valor_maior.append(1)
    else:
        valor_maior.append(0)
        
sum(valor_maior)
# Out:
# 11
